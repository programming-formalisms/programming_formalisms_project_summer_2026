# %%
import pandas as pd
import seaborn

# %%
df = pd.read_fwf("../../data/uppsala_tm_1722-2022.dat", names=['year','month','day','temp','temp2','city'])
uppsala_temps = df.groupby('year').mean()['temp']

city_dict = {
    "Uppsala"           :   1,
    "Risinge"           :   2,
    "Betna"             :   3,
    "Linköping"         :   4,
    "Stockholm"         :   5,
    "Interpolated"      :   6,
}

# %%
df[df['city'] == city_dict['Uppsala']]
df[df.iloc[:, 5] == city_dict['Uppsala']]
# Out:
#    Col1  Col2  Col3  Col4  Col5  city
# 0  1984     4    10  10.4  10.1     1
# 2  1986     6    26  22.1  21.4     1

# %%
seaborn.scatterplot(uppsala_temps)
# Out:
# <Axes: xlabel='year', ylabel='temp'>
